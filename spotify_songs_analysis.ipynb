# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Files to load
songs_data_to_load = "Resources/spotify_playlist_songs.csv"

# %%
# Read the songs data file and store it in a pandas DataFrame.
songs_data_df = pd.read_csv(songs_data_to_load)
songs_data_df
# Out:
#                     track_id  \
# 0     3SWqGa1J0M7hSBUDM0KePD
# 1     3z8h0TU7ReDPLIbEnYhWZb
# 2     0quum0TSd0de8jjpILY2xi
# 3     1sWeSMifj6Z6kZyI6z3bRc
# 4     5CQ30WqJwcep0pYcV4AMNc
# ...                      ...
# 2195  4DaByeLWrk8Zwk9H9aepvc
# 2196  0aTDDlw8ZAQM0IvgwsKvqE
# 2197  3VftjjFNQUOCmf02vbjiqK
# 2198  6UGAiIPbXtrdor1PD7PzCJ
# 2199  6pnwfWyaWjQiHCKTiZLItr
#
#                                             track_names  \
# 0                                                Legend
# 1                                     Bohemian Rhapsody
# 2                           Brawl Stars (Menu Remix V5)
# 3                                              Warriors
# 4                         Stairway to Heaven - Remaster
# ...                                                 ...
# 2195                            Drama Queen - Radio Mix
# 2196                            Maski Dolu - Club Remix
# 2197                                Jore Dos - Club Mix
# 2198  Didn't We Deserve a Look At You The Way You Re...
# 2199              Shine On You Crazy Diamond (Pts. 1-5)
#
#                   artist_ids       artist_names release_date  popularity  \
# 0     2q3GG88dVwuQPF4FmySr9I          The Score   2017-10-13          75
# 1     1dfeR4HaWDbWqFHLkxsg1d              Queen   2018-10-19          75
# 2     43iexp0Suf11TFpvR4OdPh            Hatkuvi   2020-07-06          28
# 3     53XhwfbYqKCa1cC15pYq2q    Imagine Dragons   2015-05-18          75
# 4     36QJpDe2go2KgaRleHCDTp       Led Zeppelin   1971-11-08          81
# ...                      ...                ...          ...         ...
# 2195  2IN2VBkdXOBfoXJGrAUV1O  Deep Zone Project   2017-04-01           3
# 2196  2IN2VBkdXOBfoXJGrAUV1O  Deep Zone Project   2017-04-01           3
# 2197  2IN2VBkdXOBfoXJGrAUV1O  Deep Zone Project   2017-04-01           3
# 2198  6I8R5MFTlez7rHCsH4cx0u            Shellac   1998-05-19           0
# 2199  0k17h0D3J5VfsdmQ1iZtE9         Pink Floyd   1975-09-12          68
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.601   0.757    2    -3.341     1       0.0280      0.013900
# 1            0.390   0.397    0    -9.963     0       0.0513      0.287000
# 2            0.522   0.749    5    -9.181     0       0.0278      0.000391
# 3            0.365   0.851    4    -6.238     0       0.0645      0.096400
# 4            0.338   0.340    9   -12.049     0       0.0339      0.580000
# ...            ...     ...  ...       ...   ...          ...           ...
# 2195         0.653   0.951    1    -3.020     0       0.0649      0.010300
# 2196         0.713   0.873    4    -6.366     0       0.1010      0.008860
# 2197         0.668   0.949    2    -7.156     0       0.0517      0.023000
# 2198         0.646   0.285   11   -13.824     0       0.1910      0.429000
# 2199         0.264   0.294    7   -11.941     0       0.0280      0.772000
#
#       instrumentalness  liveness  valence    tempo  duration_mins  \
# 0             0.000088    0.0727   0.4620   82.001           3.15
# 1             0.000000    0.2070   0.2460  144.031           5.92
# 2             0.872000    0.1400   0.2740  119.974           2.74
# 3             0.003000    0.2370   0.3090   78.086           2.85
# 4             0.003200    0.1160   0.1970   82.433           8.05
# ...                ...       ...      ...      ...            ...
# 2195          0.000000    0.0595   0.8230  170.050           3.11
# 2196          0.026200    0.1080   0.4020  121.996           5.04
# 2197          0.240000    0.4920   0.8320  128.031           5.94
# 2198          0.835000    0.1120   0.3860  136.007          12.32
# 2199          0.686000    0.1070   0.0402  137.937          13.52
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 2195               4
# 2196               4
# 2197               4
# 2198               3
# 2199               3
#
# [2200 rows x 19 columns]

# %%
# Check if data is null
songs_data_df.isnull().sum()
# Out:
# track_id            0
# track_names         0
# artist_ids          0
# artist_names        0
# release_date        0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_mins       0
# time_signature      0
# dtype: int64

# %%
# Check the datatype of all the columns and change the datatype to appropriate type if needed
songs_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          2200 non-null   object
#  1   track_names       2200 non-null   object
#  2   artist_ids        2200 non-null   object
#  3   artist_names      2200 non-null   object
#  4   release_date      2200 non-null   object
#  5   popularity        2200 non-null   int64
#  6   danceability      2200 non-null   float64
#  7   energy            2200 non-null   float64
#  8   key               2200 non-null   int64
#  9   loudness          2200 non-null   float64
#  10  mode              2200 non-null   int64
#  11  speechiness       2200 non-null   float64
#  12  acousticness      2200 non-null   float64
#  13  instrumentalness  2200 non-null   float64
#  14  liveness          2200 non-null   float64
#  15  valence           2200 non-null   float64
#  16  tempo             2200 non-null   float64
#  17  duration_mins     2200 non-null   float64
#  18  time_signature    2200 non-null   int64
# dtypes: float64(10), int64(4), object(5)
# memory usage: 326.7+ KB

# %%
# Change the datatype of release date to datetime and create a new column for release year
songs_data_df['release_date'] = pd.to_datetime(songs_data_df['release_date'])
songs_data_df['release_year'] = pd.DatetimeIndex(songs_data_df['release_date']).year

# %%
# Confirm all the data types 
songs_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          2200 non-null   object
#  1   track_names       2200 non-null   object
#  2   artist_ids        2200 non-null   object
#  3   artist_names      2200 non-null   object
#  4   release_date      2200 non-null   datetime64[ns]
#  5   popularity        2200 non-null   int64
#  6   danceability      2200 non-null   float64
#  7   energy            2200 non-null   float64
#  8   key               2200 non-null   int64
#  9   loudness          2200 non-null   float64
#  10  mode              2200 non-null   int64
#  11  speechiness       2200 non-null   float64
#  12  acousticness      2200 non-null   float64
#  13  instrumentalness  2200 non-null   float64
#  14  liveness          2200 non-null   float64
#  15  valence           2200 non-null   float64
#  16  tempo             2200 non-null   float64
#  17  duration_mins     2200 non-null   float64
#  18  time_signature    2200 non-null   int64
#  19  release_year      2200 non-null   int64
# dtypes: datetime64[ns](1), float64(10), int64(5), object(4)
# memory usage: 343.9+ KB

# %%
# Remove all unpopular songs
popular_songs_data_df = songs_data_df.loc[songs_data_df['popularity'] > 60]
print(len(popular_songs_data_df))
# Out:
# 344

# %%
# Creating group of audio features by year of release
popularity_by_year_df = popular_songs_data_df.groupby("release_year").mean()['popularity']
danceability_by_year_df = popular_songs_data_df.groupby("release_year").mean()['danceability']
energy_by_year_df = popular_songs_data_df.groupby("release_year").mean()['energy']
speechiness_by_year_df = popular_songs_data_df.groupby("release_year").mean()['speechiness']
acousticness_by_year_df = popular_songs_data_df.groupby("release_year").mean()['acousticness']
instrumentalness_by_year_df = popular_songs_data_df.groupby("release_year").mean()['instrumentalness']
liveness_by_year_df = popular_songs_data_df.groupby("release_year").mean()['liveness']
valence_by_year_df = popular_songs_data_df.groupby("release_year").mean()['valence']
tempo_by_year_df = popular_songs_data_df.groupby("release_year").mean()['tempo']

# popularity_by_year_df = songs_data_df.groupby("release_year").mean()['popularity']
# danceability_by_year_df = songs_data_df.groupby("release_year").mean()['danceability']
# energy_by_year_df = songs_data_df.groupby("release_year").mean()['energy']
# speechiness_by_year_df = songs_data_df.groupby("release_year").mean()['speechiness']
# acousticness_by_year_df = songs_data_df.groupby("release_year").mean()['acousticness']
# instrumentalness_by_year_df = songs_data_df.groupby("release_year").mean()['instrumentalness']
# liveness_by_year_df = songs_data_df.groupby("release_year").mean()['liveness']
# valence_by_year_df = songs_data_df.groupby("release_year").mean()['valence']
# tempo_by_year_df = songs_data_df.groupby("release_year").mean()['tempo']

#Prints to check data integrity
print(len(danceability_by_year_df))
print(len(popularity_by_year_df))
print(len(speechiness_by_year_df))
print(len(acousticness_by_year_df))
print(len(instrumentalness_by_year_df))
print(len(liveness_by_year_df))
print(len(valence_by_year_df))
print(len(tempo_by_year_df))

# # Merging into a Dataframe with audio features by year
songs_by_year_mean_df = pd.concat([danceability_by_year_df,popularity_by_year_df, speechiness_by_year_df, acousticness_by_year_df, instrumentalness_by_year_df, liveness_by_year_df, valence_by_year_df, tempo_by_year_df], axis =1)
print(len(songs_by_year_mean_df))
songs_by_year_mean_df
# Out:
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
#               danceability  popularity  speechiness  acousticness  \
# release_year
# 1949              0.469000   71.000000     0.119000      0.994000
# 1967              0.396000   72.000000     0.034500      0.326000
# 1970              0.564000   79.000000     0.055400      0.013000
# 1971              0.338000   81.000000     0.033900      0.580000
# 1972              0.495200   67.400000     0.044000      0.152920
# 1973              0.212000   65.000000     0.038400      0.963000
# 1975              0.349500   65.500000     0.030800      0.465500
# 1976              0.136000   66.000000     0.036400      0.911000
# 1977              0.428000   75.000000     0.063033      0.384333
# 1979              0.592000   61.000000     0.046800      0.008840
# 1980              0.933000   84.000000     0.161000      0.112000
# 1981              0.454000   66.000000     0.051400      0.995000
# 1982              0.233000   61.000000     0.034600      0.975000
# 1983              0.275000   70.000000     0.063600      0.890000
# 1984              0.358000   62.000000     0.035400      0.899000
# 1985              0.667000   65.000000     0.036700      0.049100
# 1986              0.128000   63.000000     0.035300      0.744000
# 1988              0.935000   67.000000     0.225000      0.014300
# 1989              0.389000   64.250000     0.043050      0.674500
# 1990              0.355000   61.000000     0.039600      0.995000
# 1991              0.314250   66.250000     0.035075      0.445081
# 1992              0.336500   69.000000     0.037400      0.496663
# 1995              0.404000   75.000000     0.062300      0.000056
# 1998              0.343000   63.000000     0.040600      0.991000
# 2002              0.308300   68.000000     0.050467      0.649267
# 2003              0.743000   85.000000     0.068300      0.003900
# 2004              0.724000   66.000000     0.099500      0.003440
# 2007              0.317750   64.250000     0.042200      0.745809
# 2009              0.453000   68.333333     0.069000      0.356737
# 2010              0.269333   63.000000     0.043367      0.975333
# 2011              0.588000   65.000000     0.038700      0.009480
# 2012              0.533100   73.200000     0.057870      0.143941
# 2013              0.594889   70.666667     0.057389      0.040810
# 2014              0.535444   74.555556     0.056578      0.081487
# 2015              0.507182   69.545455     0.072691      0.308666
# 2016              0.573231   66.384615     0.082631      0.274098
# 2017              0.617909   71.484848     0.134818      0.177947
# 2018              0.704059   71.196078     0.157133      0.199342
# 2019              0.748218   69.029703     0.218555      0.182461
# 2020              0.791952   71.238095     0.191779      0.162108
# 2021              0.688273   69.545455     0.143945      0.243983
#
#               instrumentalness  liveness   valence       tempo
# release_year
# 1949              9.370000e-01  0.094100  0.354000   72.765000
# 1967              1.240000e-04  0.109000  0.385000  133.449000
# 1970              1.690000e-01  0.349000  0.619000  112.937000
# 1971              3.200000e-03  0.116000  0.197000   82.433000
# 1972              3.486600e-05  0.227880  0.583400  124.049800
# 1973              3.300000e-03  0.130000  0.079800   84.025000
# 1975              3.433525e-01  0.282000  0.387100  120.877500
# 1976              9.160000e-01  0.109000  0.071000   58.303000
# 1977              3.600000e-07  0.158833  0.263667   88.332667
# 1979              1.550000e-02  0.050600  0.442000   92.157000
# 1980              3.120000e-01  0.163000  0.754000  109.967000
# 1981              9.430000e-01  0.073600  0.244000  130.253000
# 1982              6.010000e-01  0.143000  0.093600   94.736000
# 1983              8.420000e-01  0.186000  0.304000   73.289000
# 1984              9.600000e-01  0.103000  0.601000  144.561000
# 1985              8.940000e-04  0.064100  0.657000  134.212000
# 1986              9.420000e-01  0.107000  0.098800   85.314000
# 1988              1.530000e-06  0.298000  0.624000  105.641000
# 1989              6.504150e-01  0.197200  0.722500  140.818500
# 1990              9.260000e-01  0.098600  0.092200   67.946000
# 1991              4.566183e-01  0.169625  0.426250   92.078750
# 1992              4.610118e-01  0.114000  0.335500   85.019000
# 1995              8.360000e-01  0.046600  0.475000  121.864000
# 1998              9.200000e-01  0.100000  0.037800   60.228000
# 2002              5.773665e-01  0.186900  0.364200  115.205667
# 2003              1.180000e-01  0.337000  0.278000  123.596000
# 2004              4.720000e-05  0.300000  0.818000  103.022000
# 2007              6.852500e-01  0.098650  0.163100  104.503750
# 2009              3.083340e-01  0.222433  0.361800  142.077000
# 2010              9.136667e-01  0.086200  0.124667   60.305000
# 2011              0.000000e+00  0.113000  0.271000  126.027000
# 2012              9.134325e-02  0.224100  0.412430  114.229100
# 2013              9.205433e-04  0.316000  0.496778  126.802444
# 2014              7.472144e-04  0.204856  0.473222  125.373778
# 2015              1.659690e-01  0.268309  0.448364  125.747545
# 2016              1.387235e-01  0.179562  0.395100  105.043077
# 2017              5.967852e-02  0.159815  0.512264  116.596152
# 2018              3.601743e-02  0.195924  0.542055  123.871686
# 2019              3.388898e-02  0.162648  0.547871  129.065347
# 2020              3.967192e-02  0.197083  0.530802  127.699286
# 2021              2.945455e-04  0.187436  0.647545  132.746091

# %%
# Creating group of audio features by artist
popularity_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['popularity']
danceability_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['danceability']
energy_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['energy']
speechiness_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['speechiness']
acousticness_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['acousticness']
instrumentalness_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['instrumentalness']
liveness_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['liveness']
valence_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['valence']
tempo_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['tempo']

# # Prints to check data integrity
# print(len(danceability_by_artist_df))
# print(len(popularity_by_artist_df))
# print(len(speechiness_by_artist_df))
# print(len(acousticness_by_artist_df))
# print(len(instrumentalness_by_artist_df))
# print(len(liveness_by_artist_df))
# print(len(valence_by_artist_df))
# print(len(tempo_by_artist_df))

# Merging into a Dataframe with audio features by artist
songs_by_artist_df = pd.concat([danceability_by_artist_df,popularity_by_artist_df, speechiness_by_artist_df, acousticness_by_artist_df, instrumentalness_by_artist_df, liveness_by_artist_df, valence_by_artist_df, tempo_by_artist_df], axis =1)
print(len(songs_by_artist_df))
songs_by_artist_df
# Out:
# 209
#                                       danceability  popularity  speechiness  \
# artist_names  artist_ids
# $NOT          5IbEL2xjRtKsunfmsahLuO         0.847        78.0     0.416000
# 24kGoldn      6fWVd57NKTalqvmjRd2t8Z         0.704        76.5     0.081125
# 88GLAM        2I9SLklAOG0vdMiUUMNxRl         0.764        66.0     0.065500
# Adam Jensen   7ymrIsmp4vE7vAtcS12J4D         0.716        61.0     0.040600
# Afrojack      4D75GcNG95ebPtNvoNVXhz         0.523        66.0     0.064400
# ...                                            ...         ...          ...
# iann dior     6ASri4ePR7RlsvIQgWPJpS         0.695        67.0     0.124000
# ilyTOMMY      4XWaILHqySwH1y6LhlYcsb         0.683        65.0     0.097800
# lil ricefield 2lNuUKrRrHRQ6cYVmrAazL         0.834        61.0     0.158000
# pewdiepie     1JOdUvDAzNy3L37rZ4Nigr         0.795        64.0     0.259000
# tobi lou      4T8NIfZmVY6TJFqVzN6X49         0.734        66.0     0.057100
#
#                                       acousticness  instrumentalness  \
# artist_names  artist_ids
# $NOT          5IbEL2xjRtKsunfmsahLuO       0.81000          0.000013
# 24kGoldn      6fWVd57NKTalqvmjRd2t8Z       0.14125          0.000000
# 88GLAM        2I9SLklAOG0vdMiUUMNxRl       0.01660          0.000001
# Adam Jensen   7ymrIsmp4vE7vAtcS12J4D       0.00180          0.006960
# Afrojack      4D75GcNG95ebPtNvoNVXhz       0.03360          0.000000
# ...                                            ...               ...
# iann dior     6ASri4ePR7RlsvIQgWPJpS       0.00202          0.000000
# ilyTOMMY      4XWaILHqySwH1y6LhlYcsb       0.30200          0.498000
# lil ricefield 2lNuUKrRrHRQ6cYVmrAazL       0.02780          0.000000
# pewdiepie     1JOdUvDAzNy3L37rZ4Nigr       0.01380          0.000000
# tobi lou      4T8NIfZmVY6TJFqVzN6X49       0.24300          0.000000
#
#                                       liveness  valence     tempo
# artist_names  artist_ids
# $NOT          5IbEL2xjRtKsunfmsahLuO  0.325000  0.48800   79.9750
# 24kGoldn      6fWVd57NKTalqvmjRd2t8Z  0.167625  0.61875  128.7495
# 88GLAM        2I9SLklAOG0vdMiUUMNxRl  0.103000  0.59400  150.0210
# Adam Jensen   7ymrIsmp4vE7vAtcS12J4D  0.113000  0.34900  129.0400
# Afrojack      4D75GcNG95ebPtNvoNVXhz  0.144000  0.34600  127.0490
# ...                                        ...      ...       ...
# iann dior     6ASri4ePR7RlsvIQgWPJpS  0.167000  0.38800   80.0290
# ilyTOMMY      4XWaILHqySwH1y6LhlYcsb  0.097200  0.61500  160.0120
# lil ricefield 2lNuUKrRrHRQ6cYVmrAazL  0.167000  0.46500  110.0380
# pewdiepie     1JOdUvDAzNy3L37rZ4Nigr  0.113000  0.53800  149.9610
# tobi lou      4T8NIfZmVY6TJFqVzN6X49  0.101000  0.51200  156.0400
#
# [209 rows x 8 columns]

# %%
# Removing all artists that have popularity below 70
songs_by_popular_artist_df = songs_by_artist_df.loc[(songs_by_artist_df['popularity'] > 70)]
print(len(songs_by_popular_artist_df))
songs_by_popular_artist_df
# Out:
# 68
#                                          danceability  popularity  \
# artist_names     artist_ids
# $NOT             5IbEL2xjRtKsunfmsahLuO         0.847   78.000000
# 24kGoldn         6fWVd57NKTalqvmjRd2t8Z         0.704   76.500000
# Alice In Chains  64tNsm6TnZe2zpcMVMOoHL         0.305   73.000000
# American Authors 0MlOPi3zIDMVrfA9R04Fe3         0.620   72.000000
# Aminé            3Gm5F95VdRxW3mqCn8RPBJ         0.754   78.000000
# ...                                               ...         ...
# Y2K              6USMTwO0MNDnKte5a5h0xx         0.843   79.000000
# YNW Melly        1cNDP5yjU5vjeR8qMf4grg         0.784   75.333333
# Young Thug       50co4Is1HCEo8bhOyUWKpn         0.855   75.000000
# fun.             5nCi3BB41mBaMH9gfr6Su0         0.672   72.000000
# grandson         4ZgQDCtRqZlhLswVS6MHN4         0.450   71.500000
#
#                                          speechiness  acousticness  \
# artist_names     artist_ids
# $NOT             5IbEL2xjRtKsunfmsahLuO     0.416000      0.810000
# 24kGoldn         6fWVd57NKTalqvmjRd2t8Z     0.081125      0.141250
# Alice In Chains  64tNsm6TnZe2zpcMVMOoHL     0.039800      0.000327
# American Authors 0MlOPi3zIDMVrfA9R04Fe3     0.048600      0.066200
# Aminé            3Gm5F95VdRxW3mqCn8RPBJ     0.099100      0.073000
# ...                                              ...           ...
# Y2K              6USMTwO0MNDnKte5a5h0xx     0.084600      0.178000
# YNW Melly        1cNDP5yjU5vjeR8qMf4grg     0.154967      0.213600
# Young Thug       50co4Is1HCEo8bhOyUWKpn     0.235000      0.063000
# fun.             5nCi3BB41mBaMH9gfr6Su0     0.050600      0.017800
# grandson         4ZgQDCtRqZlhLswVS6MHN4     0.102950      0.010140
#
#                                          instrumentalness  liveness   valence  \
# artist_names     artist_ids
# $NOT             5IbEL2xjRtKsunfmsahLuO          0.000013  0.325000  0.488000
# 24kGoldn         6fWVd57NKTalqvmjRd2t8Z          0.000000  0.167625  0.618750
# Alice In Chains  64tNsm6TnZe2zpcMVMOoHL          0.000024  0.091000  0.586000
# American Authors 0MlOPi3zIDMVrfA9R04Fe3          0.000000  0.078800  0.675000
# Aminé            3Gm5F95VdRxW3mqCn8RPBJ          0.000000  0.193000  0.423000
# ...                                                   ...       ...       ...
# Y2K              6USMTwO0MNDnKte5a5h0xx          0.000000  0.137000  0.495000
# YNW Melly        1cNDP5yjU5vjeR8qMf4grg          0.000001  0.110133  0.595667
# Young Thug       50co4Is1HCEo8bhOyUWKpn          0.000000  0.077200  0.559000
# fun.             5nCi3BB41mBaMH9gfr6Su0          0.000068  0.092700  0.392000
# grandson         4ZgQDCtRqZlhLswVS6MHN4          0.001051  0.071100  0.407500
#
#                                               tempo
# artist_names     artist_ids
# $NOT             5IbEL2xjRtKsunfmsahLuO   79.975000
# 24kGoldn         6fWVd57NKTalqvmjRd2t8Z  128.749500
# Alice In Chains  64tNsm6TnZe2zpcMVMOoHL  100.675000
# American Authors 0MlOPi3zIDMVrfA9R04Fe3  126.041000
# Aminé            3Gm5F95VdRxW3mqCn8RPBJ  128.981000
# ...                                             ...
# Y2K              6USMTwO0MNDnKte5a5h0xx  129.972000
# YNW Melly        1cNDP5yjU5vjeR8qMf4grg  119.980667
# Young Thug       50co4Is1HCEo8bhOyUWKpn  111.997000
# fun.             5nCi3BB41mBaMH9gfr6Su0  107.938000
# grandson         4ZgQDCtRqZlhLswVS6MHN4  148.006000
#
# [68 rows x 8 columns]

# %%
# Songs that are most popular
most_popular_songs_df = songs_data_df.loc[(songs_data_df['popularity'] > 70)]
print(len(most_popular_songs_df))
# Out:
# 135
