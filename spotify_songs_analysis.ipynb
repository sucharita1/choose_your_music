# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Files to load
songs_data_to_load = "Resources/spotify_playlist_songs.csv"

# %%
# Read the songs data file and store it in a pandas DataFrame.
songs_data_df = pd.read_csv(songs_data_to_load)
songs_data_df
# Out:
#                     track_id  \
# 0     3SWqGa1J0M7hSBUDM0KePD
# 1     3z8h0TU7ReDPLIbEnYhWZb
# 2     0quum0TSd0de8jjpILY2xi
# 3     1sWeSMifj6Z6kZyI6z3bRc
# 4     5CQ30WqJwcep0pYcV4AMNc
# ...                      ...
# 2195  4DaByeLWrk8Zwk9H9aepvc
# 2196  0aTDDlw8ZAQM0IvgwsKvqE
# 2197  3VftjjFNQUOCmf02vbjiqK
# 2198  6UGAiIPbXtrdor1PD7PzCJ
# 2199  6pnwfWyaWjQiHCKTiZLItr
#
#                                             track_names  \
# 0                                                Legend
# 1                                     Bohemian Rhapsody
# 2                           Brawl Stars (Menu Remix V5)
# 3                                              Warriors
# 4                         Stairway to Heaven - Remaster
# ...                                                 ...
# 2195                            Drama Queen - Radio Mix
# 2196                            Maski Dolu - Club Remix
# 2197                                Jore Dos - Club Mix
# ...

# %%
# Check if data is null
songs_data_df.isnull().sum()
# Out:
# track_id            0
# track_names         0
# artist_ids          0
# artist_names        0
# release_date        0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_mins       0
# time_signature      0
# dtype: int64

# %%
# Check the datatype of all the columns and change the datatype to appropriate type if needed
songs_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          2200 non-null   object
#  1   track_names       2200 non-null   object
#  2   artist_ids        2200 non-null   object
#  3   artist_names      2200 non-null   object
#  4   release_date      2200 non-null   object
#  5   popularity        2200 non-null   int64
#  6   danceability      2200 non-null   float64
#  7   energy            2200 non-null   float64
#  8   key               2200 non-null   int64
#  9   loudness          2200 non-null   float64
#  10  mode              2200 non-null   int64
#  11  speechiness       2200 non-null   float64
#  12  acousticness      2200 non-null   float64
#  13  instrumentalness  2200 non-null   float64
#  14  liveness          2200 non-null   float64
#  15  valence           2200 non-null   float64
# ...

# %%
# Change the datatype of release date to datetime and create a new column for release year
songs_data_df['release_date'] = pd.to_datetime(songs_data_df['release_date'])
songs_data_df['release_year'] = pd.DatetimeIndex(songs_data_df['release_date']).year

# %%
# Confirm all the data types 
songs_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          2200 non-null   object
#  1   track_names       2200 non-null   object
#  2   artist_ids        2200 non-null   object
#  3   artist_names      2200 non-null   object
#  4   release_date      2200 non-null   datetime64[ns]
#  5   popularity        2200 non-null   int64
#  6   danceability      2200 non-null   float64
#  7   energy            2200 non-null   float64
#  8   key               2200 non-null   int64
#  9   loudness          2200 non-null   float64
#  10  mode              2200 non-null   int64
#  11  speechiness       2200 non-null   float64
#  12  acousticness      2200 non-null   float64
#  13  instrumentalness  2200 non-null   float64
#  14  liveness          2200 non-null   float64
#  15  valence           2200 non-null   float64
# ...

# %%
# Creating group of audio features by year of release
popularity_by_year_df = songs_data_df.groupby("release_year").agg({'popularity':sum})
danceability_by_year_df = songs_data_df.groupby("release_year").agg({'danceability': sum})
energy_by_year_df = songs_data_df.groupby("release_year").agg({'energy':sum})
speechiness_by_year_df = songs_data_df.groupby("release_year").agg({'speechiness':sum})
acousticness_by_year_df = songs_data_df.groupby("release_year").agg({'acousticness':sum})
instrumentalness_by_year_df = songs_data_df.groupby("release_year").agg({'instrumentalness':sum})
liveness_by_year_df = songs_data_df.groupby("release_year").agg({'liveness':sum})
valence_by_year_df = songs_data_df.groupby("release_year").agg({'valence':sum})
tempo_by_year_df = songs_data_df.groupby("release_year").agg({'tempo':sum})

#Prints to check data integrity
# print(len(danceability_by_year_df))
# print(len(popularity_by_year_df))
# print(len(speechiness_by_year_df))
# print(len(acousticness_by_year_df))
# print(len(instrumentalness_by_year_df))
# print(len(liveness_by_year_df))
# print(len(valence_by_year_df))
# print(len(tempo_by_year_df))

# Merging into a Dataframe with audio features by year
songs_by_year_df = pd.concat([danceability_by_year_df,popularity_by_year_df, speechiness_by_year_df, acousticness_by_year_df, instrumentalness_by_year_df, liveness_by_year_df, valence_by_year_df, tempo_by_year_df], axis =1)
print(len(songs_by_year_df))
songs_by_year_df
# Out:
# 60
#               danceability  popularity  speechiness  acousticness  \
# release_year
# 1949                0.4690          71       0.1190      0.994000
# 1955                0.1350          15       0.0394      0.818000
# 1962                0.3860           8       0.0402      0.994000
# 1963                0.5810          51       0.0366      0.861000
# 1964                0.3630          51       0.0689      0.976000
# 1966                1.2480          73       0.1436      2.876000
# 1967                0.3960          72       0.0345      0.326000
# 1968                0.9660          53       0.3894      0.829000
# 1970                0.5640          79       0.0554      0.013000
# 1971                2.0360         223       0.1766      1.500200
# 1972                5.5300         666       0.4612      1.966000
# 1973                3.0830         380       0.4165      3.730300
# 1974                0.5700          12       0.0332      0.024200
# ...

# %%
# Creating group of audio features by artist
popularity_by_artist_df = songs_data_df.groupby(['artist_ids','artist_names']).agg({'popularity':sum})
danceability_by_artist_df = songs_data_df.groupby(['artist_ids','artist_names']).agg({'danceability': sum})
energy_by_artist_df = songs_data_df.groupby(['artist_ids','artist_names']).agg({'energy':sum})
speechiness_by_artist_df = songs_data_df.groupby(['artist_ids','artist_names']).agg({'speechiness':sum})
acousticness_by_artist_df = songs_data_df.groupby(['artist_ids','artist_names']).agg({'acousticness':sum})
instrumentalness_by_artist_df = songs_data_df.groupby(['artist_ids','artist_names']).agg({'instrumentalness':sum})
liveness_by_artist_df = songs_data_df.groupby(['artist_ids','artist_names']).agg({'liveness':sum})
valence_by_artist_df = songs_data_df.groupby(['artist_ids','artist_names']).agg({'valence':sum})
tempo_by_artist_df = songs_data_df.groupby(['artist_ids','artist_names']).agg({'tempo':sum})

#Prints to check data integrity
# print(len(danceability_by_artist_df))
# print(len(popularity_by_artist_df))
# print(len(speechiness_by_artist_df))
# print(len(acousticness_by_artist_df))
# print(len(instrumentalness_by_artist_df))
# print(len(liveness_by_artist_df))
# print(len(valence_by_artist_df))
# print(len(tempo_by_artist_df))

# Merging into a Dataframe with audio features by artist
songs_by_artist_df = pd.concat([danceability_by_artist_df,popularity_by_artist_df, speechiness_by_artist_df, acousticness_by_artist_df, instrumentalness_by_artist_df, liveness_by_artist_df, valence_by_artist_df, tempo_by_artist_df], axis =1)
print(len(songs_by_artist_df))
songs_by_artist_df
# Out:
# 1066
#                                           danceability  popularity  \
# artist_ids             artist_names
# 00sazWvoTLOqg5MFwC68Um Yann Tiersen              0.484          54
# 01SVXm0DbeIiWZloIlDyOK Jalopy Bungus             0.930          18
# 01aC2ikO4Xgb2LUpf9JfKp Gary Clark Jr.            0.447          65
# 0274yz3YLvjWaqA8dhoPDv Rontae Don't Play         0.893          44
# 02hku5R1SCUiTPydXMdKBp seiji oda                 0.827          36
# ...                                                ...         ...
# 7ySZXevcgRfQ8OBL76GMSz svrite                    2.376         115
# 7ymrIsmp4vE7vAtcS12J4D Adam Jensen               1.243         120
# 7yv4x9prNWnvD8a0zqAgwC Lil HBK                   0.658          14
# 7zbjOKVy1RxAwkWRSO9DgS Lil Bersa                 0.906           0
# 7zmqrvVAIRY3qS1AL8gfqP CedanVibe                 0.601          32
#
#                                           speechiness  acousticness  \
# artist_ids             artist_names
# ...
