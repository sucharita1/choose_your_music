# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Files to load
songs_data_to_load = "Resources/spotify_playlist_songs.csv"

# %%
# Read the songs data file and store it in a pandas DataFrame.
songs_data_df = pd.read_csv(songs_data_to_load)
songs_data_df
# Out:
#                     track_id  \
# 0     3SWqGa1J0M7hSBUDM0KePD
# 1     3z8h0TU7ReDPLIbEnYhWZb
# 2     0quum0TSd0de8jjpILY2xi
# 3     1sWeSMifj6Z6kZyI6z3bRc
# 4     5CQ30WqJwcep0pYcV4AMNc
# ...                      ...
# 2195  4DaByeLWrk8Zwk9H9aepvc
# 2196  0aTDDlw8ZAQM0IvgwsKvqE
# 2197  3VftjjFNQUOCmf02vbjiqK
# 2198  6UGAiIPbXtrdor1PD7PzCJ
# 2199  6pnwfWyaWjQiHCKTiZLItr
#
#                                             track_names  \
# 0                                                Legend
# 1                                     Bohemian Rhapsody
# 2                           Brawl Stars (Menu Remix V5)
# 3                                              Warriors
# 4                         Stairway to Heaven - Remaster
# ...                                                 ...
# 2195                            Drama Queen - Radio Mix
# 2196                            Maski Dolu - Club Remix
# 2197                                Jore Dos - Club Mix
# 2198  Didn't We Deserve a Look At You The Way You Re...
# 2199              Shine On You Crazy Diamond (Pts. 1-5)
#
#                   artist_ids       artist_names release_date  popularity  \
# 0     2q3GG88dVwuQPF4FmySr9I          The Score   2017-10-13          75
# 1     1dfeR4HaWDbWqFHLkxsg1d              Queen   2018-10-19          75
# 2     43iexp0Suf11TFpvR4OdPh            Hatkuvi   2020-07-06          28
# 3     53XhwfbYqKCa1cC15pYq2q    Imagine Dragons   2015-05-18          75
# 4     36QJpDe2go2KgaRleHCDTp       Led Zeppelin   1971-11-08          81
# ...                      ...                ...          ...         ...
# 2195  2IN2VBkdXOBfoXJGrAUV1O  Deep Zone Project   2017-04-01           3
# 2196  2IN2VBkdXOBfoXJGrAUV1O  Deep Zone Project   2017-04-01           3
# 2197  2IN2VBkdXOBfoXJGrAUV1O  Deep Zone Project   2017-04-01           3
# 2198  6I8R5MFTlez7rHCsH4cx0u            Shellac   1998-05-19           0
# 2199  0k17h0D3J5VfsdmQ1iZtE9         Pink Floyd   1975-09-12          68
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.601   0.757    2    -3.341     1       0.0280      0.013900
# 1            0.390   0.397    0    -9.963     0       0.0513      0.287000
# 2            0.522   0.749    5    -9.181     0       0.0278      0.000391
# 3            0.365   0.851    4    -6.238     0       0.0645      0.096400
# 4            0.338   0.340    9   -12.049     0       0.0339      0.580000
# ...            ...     ...  ...       ...   ...          ...           ...
# 2195         0.653   0.951    1    -3.020     0       0.0649      0.010300
# 2196         0.713   0.873    4    -6.366     0       0.1010      0.008860
# 2197         0.668   0.949    2    -7.156     0       0.0517      0.023000
# 2198         0.646   0.285   11   -13.824     0       0.1910      0.429000
# 2199         0.264   0.294    7   -11.941     0       0.0280      0.772000
#
#       instrumentalness  liveness  valence    tempo  duration_mins  \
# 0             0.000088    0.0727   0.4620   82.001           3.15
# 1             0.000000    0.2070   0.2460  144.031           5.92
# 2             0.872000    0.1400   0.2740  119.974           2.74
# 3             0.003000    0.2370   0.3090   78.086           2.85
# 4             0.003200    0.1160   0.1970   82.433           8.05
# ...                ...       ...      ...      ...            ...
# 2195          0.000000    0.0595   0.8230  170.050           3.11
# 2196          0.026200    0.1080   0.4020  121.996           5.04
# 2197          0.240000    0.4920   0.8320  128.031           5.94
# 2198          0.835000    0.1120   0.3860  136.007          12.32
# 2199          0.686000    0.1070   0.0402  137.937          13.52
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 2195               4
# 2196               4
# 2197               4
# 2198               3
# 2199               3
#
# [2200 rows x 19 columns]

# %%
# Check if data is null
songs_data_df.isnull().sum()
# Out:
# track_id            0
# track_names         0
# artist_ids          0
# artist_names        0
# release_date        0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_mins       0
# time_signature      0
# dtype: int64

# %%
# Check the datatype of all the columns and change the datatype to appropriate type if needed
songs_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          2200 non-null   object
#  1   track_names       2200 non-null   object
#  2   artist_ids        2200 non-null   object
#  3   artist_names      2200 non-null   object
#  4   release_date      2200 non-null   object
#  5   popularity        2200 non-null   int64
#  6   danceability      2200 non-null   float64
#  7   energy            2200 non-null   float64
#  8   key               2200 non-null   int64
#  9   loudness          2200 non-null   float64
#  10  mode              2200 non-null   int64
#  11  speechiness       2200 non-null   float64
#  12  acousticness      2200 non-null   float64
#  13  instrumentalness  2200 non-null   float64
#  14  liveness          2200 non-null   float64
#  15  valence           2200 non-null   float64
#  16  tempo             2200 non-null   float64
#  17  duration_mins     2200 non-null   float64
#  18  time_signature    2200 non-null   int64
# dtypes: float64(10), int64(4), object(5)
# memory usage: 326.7+ KB

# %%
# Check for reliablity of data
songs_data_df.describe()
# Out:
#         popularity  danceability       energy          key     loudness  \
# count  2200.000000   2200.000000  2200.000000  2200.000000  2200.000000
# mean     35.518182      0.641141     0.585153     4.993636    -9.762125
# std      23.072510      0.219862     0.269700     3.654715     7.458287
# min       0.000000      0.000000     0.001100     0.000000   -44.526000
# 25%      16.000000      0.498000     0.446000     1.000000   -10.733000
# 50%      37.000000      0.682000     0.625000     5.000000    -7.285500
# 75%      54.000000      0.822000     0.795250     8.000000    -5.252750
# max      90.000000      0.981000     1.000000    11.000000     4.294000
#
#               mode  speechiness  acousticness  instrumentalness     liveness  \
# count  2200.000000  2200.000000   2200.000000       2200.000000  2200.000000
# mean      0.616364     0.160856      0.262988          0.148066     0.183786
# std       0.486382     0.150869      0.334801          0.314949     0.150067
# min       0.000000     0.000000      0.000005          0.000000     0.024900
# 25%       0.000000     0.045300      0.018700          0.000000     0.093700
# 50%       1.000000     0.085350      0.099450          0.000003     0.123000
# 75%       1.000000     0.256250      0.369000          0.008563     0.230000
# max       1.000000     0.916000      0.996000          0.982000     0.977000
#
#            valence        tempo  duration_mins  time_signature
# count  2200.000000  2200.000000    2200.000000     2200.000000
# mean      0.479494   121.608977       3.388045        3.932273
# std       0.241279    29.808615       2.926606        0.394890
# min       0.000000     0.000000       0.520000        0.000000
# 25%       0.307000    98.144000       2.300000        4.000000
# 50%       0.495000   126.014000       2.990000        4.000000
# 75%       0.663000   140.982500       3.662500        4.000000
# max       0.984000   212.246000      76.790000        5.000000

# %%
# Change the datatype of release date to datetime and create a new column for release year
songs_data_df['release_date'] = pd.to_datetime(songs_data_df['release_date'])
songs_data_df['release_year'] = pd.DatetimeIndex(songs_data_df['release_date']).year

# normalize tempo
# Normalize tempo values
column = songs_data_df["tempo"]
max_tempo = column.max()

songs_data_df['tempo'] = songs_data_df['tempo'].apply(lambda x: x/max_tempo)
songs_data_df
# Out:
#                     track_id  \
# 0     3SWqGa1J0M7hSBUDM0KePD
# 1     3z8h0TU7ReDPLIbEnYhWZb
# 2     0quum0TSd0de8jjpILY2xi
# 3     1sWeSMifj6Z6kZyI6z3bRc
# 4     5CQ30WqJwcep0pYcV4AMNc
# ...                      ...
# 2195  4DaByeLWrk8Zwk9H9aepvc
# 2196  0aTDDlw8ZAQM0IvgwsKvqE
# 2197  3VftjjFNQUOCmf02vbjiqK
# 2198  6UGAiIPbXtrdor1PD7PzCJ
# 2199  6pnwfWyaWjQiHCKTiZLItr
#
#                                             track_names  \
# 0                                                Legend
# 1                                     Bohemian Rhapsody
# 2                           Brawl Stars (Menu Remix V5)
# 3                                              Warriors
# 4                         Stairway to Heaven - Remaster
# ...                                                 ...
# 2195                            Drama Queen - Radio Mix
# 2196                            Maski Dolu - Club Remix
# 2197                                Jore Dos - Club Mix
# 2198  Didn't We Deserve a Look At You The Way You Re...
# 2199              Shine On You Crazy Diamond (Pts. 1-5)
#
#                   artist_ids       artist_names release_date  popularity  \
# 0     2q3GG88dVwuQPF4FmySr9I          The Score   2017-10-13          75
# 1     1dfeR4HaWDbWqFHLkxsg1d              Queen   2018-10-19          75
# 2     43iexp0Suf11TFpvR4OdPh            Hatkuvi   2020-07-06          28
# 3     53XhwfbYqKCa1cC15pYq2q    Imagine Dragons   2015-05-18          75
# 4     36QJpDe2go2KgaRleHCDTp       Led Zeppelin   1971-11-08          81
# ...                      ...                ...          ...         ...
# 2195  2IN2VBkdXOBfoXJGrAUV1O  Deep Zone Project   2017-04-01           3
# 2196  2IN2VBkdXOBfoXJGrAUV1O  Deep Zone Project   2017-04-01           3
# 2197  2IN2VBkdXOBfoXJGrAUV1O  Deep Zone Project   2017-04-01           3
# 2198  6I8R5MFTlez7rHCsH4cx0u            Shellac   1998-05-19           0
# 2199  0k17h0D3J5VfsdmQ1iZtE9         Pink Floyd   1975-09-12          68
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.601   0.757    2    -3.341     1       0.0280      0.013900
# 1            0.390   0.397    0    -9.963     0       0.0513      0.287000
# 2            0.522   0.749    5    -9.181     0       0.0278      0.000391
# 3            0.365   0.851    4    -6.238     0       0.0645      0.096400
# 4            0.338   0.340    9   -12.049     0       0.0339      0.580000
# ...            ...     ...  ...       ...   ...          ...           ...
# 2195         0.653   0.951    1    -3.020     0       0.0649      0.010300
# 2196         0.713   0.873    4    -6.366     0       0.1010      0.008860
# 2197         0.668   0.949    2    -7.156     0       0.0517      0.023000
# 2198         0.646   0.285   11   -13.824     0       0.1910      0.429000
# 2199         0.264   0.294    7   -11.941     0       0.0280      0.772000
#
#       instrumentalness  liveness  valence     tempo  duration_mins  \
# 0             0.000088    0.0727   0.4620  0.386349           3.15
# 1             0.000000    0.2070   0.2460  0.678604           5.92
# 2             0.872000    0.1400   0.2740  0.565259           2.74
# 3             0.003000    0.2370   0.3090  0.367903           2.85
# 4             0.003200    0.1160   0.1970  0.388384           8.05
# ...                ...       ...      ...       ...            ...
# 2195          0.000000    0.0595   0.8230  0.801193           3.11
# 2196          0.026200    0.1080   0.4020  0.574786           5.04
# 2197          0.240000    0.4920   0.8320  0.603220           5.94
# 2198          0.835000    0.1120   0.3860  0.640799          12.32
# 2199          0.686000    0.1070   0.0402  0.649892          13.52
#
#       time_signature  release_year
# 0                  4          2017
# 1                  4          2018
# 2                  4          2020
# 3                  4          2015
# 4                  4          1971
# ...              ...           ...
# 2195               4          2017
# 2196               4          2017
# 2197               4          2017
# 2198               3          1998
# 2199               3          1975
#
# [2200 rows x 20 columns]

# %%
# Confirm all the data types 
songs_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          2200 non-null   object
#  1   track_names       2200 non-null   object
#  2   artist_ids        2200 non-null   object
#  3   artist_names      2200 non-null   object
#  4   release_date      2200 non-null   datetime64[ns]
#  5   popularity        2200 non-null   int64
#  6   danceability      2200 non-null   float64
#  7   energy            2200 non-null   float64
#  8   key               2200 non-null   int64
#  9   loudness          2200 non-null   float64
#  10  mode              2200 non-null   int64
#  11  speechiness       2200 non-null   float64
#  12  acousticness      2200 non-null   float64
#  13  instrumentalness  2200 non-null   float64
#  14  liveness          2200 non-null   float64
#  15  valence           2200 non-null   float64
#  16  tempo             2200 non-null   float64
#  17  duration_mins     2200 non-null   float64
#  18  time_signature    2200 non-null   int64
#  19  release_year      2200 non-null   int64
# dtypes: datetime64[ns](1), float64(10), int64(5), object(4)
# memory usage: 343.9+ KB

# %%
# Remove all unpopular songs
popular_songs_data_df = songs_data_df.loc[songs_data_df['popularity'] > 60]
print(len(popular_songs_data_df))
# Out:
# 344

# %%
# Creating group of audio features by year of release
popularity_by_year_df = popular_songs_data_df.groupby("release_year").mean()['popularity']
danceability_by_year_df = popular_songs_data_df.groupby("release_year").mean()['danceability']
energy_by_year_df = popular_songs_data_df.groupby("release_year").mean()['energy']
speechiness_by_year_df = popular_songs_data_df.groupby("release_year").mean()['speechiness']
acousticness_by_year_df = popular_songs_data_df.groupby("release_year").mean()['acousticness']
instrumentalness_by_year_df = popular_songs_data_df.groupby("release_year").mean()['instrumentalness']
liveness_by_year_df = popular_songs_data_df.groupby("release_year").mean()['liveness']
valence_by_year_df = popular_songs_data_df.groupby("release_year").mean()['valence']
tempo_by_year_df = popular_songs_data_df.groupby("release_year").mean()['tempo']

# #Prints to check data integrity
# print(len(danceability_by_year_df))
# print(len(popularity_by_year_df))
# print(len(speechiness_by_year_df))
# print(len(acousticness_by_year_df))
# print(len(instrumentalness_by_year_df))
# print(len(liveness_by_year_df))
# print(len(valence_by_year_df))
# print(len(tempo_by_year_df))

# # Merging into a Dataframe with audio features by year
songs_by_year_df = pd.concat([danceability_by_year_df,popularity_by_year_df, energy_by_year_df, speechiness_by_year_df, acousticness_by_year_df, instrumentalness_by_year_df, liveness_by_year_df, valence_by_year_df, tempo_by_year_df], axis =1)
print(len(songs_by_year_df))
songs_by_year_df
# Out:
# 41
#               danceability  popularity    energy  speechiness  acousticness  \
# release_year
# 1949              0.469000   71.000000  0.012800     0.119000      0.994000
# 1967              0.396000   72.000000  0.473000     0.034500      0.326000
# 1970              0.564000   79.000000  0.932000     0.055400      0.013000
# 1971              0.338000   81.000000  0.340000     0.033900      0.580000
# 1972              0.495200   67.400000  0.563400     0.044000      0.152920
# 1973              0.212000   65.000000  0.301000     0.038400      0.963000
# 1975              0.349500   65.500000  0.369000     0.030800      0.465500
# 1976              0.136000   66.000000  0.164000     0.036400      0.911000
# 1977              0.428000   75.000000  0.430333     0.063033      0.384333
# 1979              0.592000   61.000000  0.882000     0.046800      0.008840
# 1980              0.933000   84.000000  0.528000     0.161000      0.112000
# 1981              0.454000   66.000000  0.013900     0.051400      0.995000
# 1982              0.233000   61.000000  0.025200     0.034600      0.975000
# 1983              0.275000   70.000000  0.157000     0.063600      0.890000
# 1984              0.358000   62.000000  0.167000     0.035400      0.899000
# 1985              0.667000   65.000000  0.655000     0.036700      0.049100
# 1986              0.128000   63.000000  0.132000     0.035300      0.744000
# 1988              0.935000   67.000000  0.805000     0.225000      0.014300
# 1989              0.389000   64.250000  0.504575     0.043050      0.674500
# 1990              0.355000   61.000000  0.016400     0.039600      0.995000
# 1991              0.314250   66.250000  0.503300     0.035075      0.445081
# 1992              0.336500   69.000000  0.418315     0.037400      0.496663
# 1995              0.404000   75.000000  0.720000     0.062300      0.000056
# 1998              0.343000   63.000000  0.034200     0.040600      0.991000
# 2002              0.308300   68.000000  0.267200     0.050467      0.649267
# 2003              0.743000   85.000000  0.446000     0.068300      0.003900
# 2004              0.724000   66.000000  0.891000     0.099500      0.003440
# 2007              0.317750   64.250000  0.211878     0.042200      0.745809
# 2009              0.453000   68.333333  0.565993     0.069000      0.356737
# 2010              0.269333   63.000000  0.059023     0.043367      0.975333
# 2011              0.588000   65.000000  0.694000     0.038700      0.009480
# 2012              0.533100   73.200000  0.729800     0.057870      0.143941
# 2013              0.594889   70.666667  0.849000     0.057389      0.040810
# 2014              0.535444   74.555556  0.788111     0.056578      0.081487
# 2015              0.507182   69.545455  0.688964     0.072691      0.308666
# 2016              0.573231   66.384615  0.574085     0.082631      0.274098
# 2017              0.617909   71.484848  0.687796     0.134818      0.177947
# 2018              0.704059   71.196078  0.649196     0.157133      0.199342
# 2019              0.748218   69.029703  0.603839     0.218555      0.182461
# 2020              0.791952   71.238095  0.567174     0.191779      0.162108
# 2021              0.688273   69.545455  0.637909     0.143945      0.243983
#
#               instrumentalness  liveness   valence     tempo
# release_year
# 1949              9.370000e-01  0.094100  0.354000  0.342833
# 1967              1.240000e-04  0.109000  0.385000  0.628747
# 1970              1.690000e-01  0.349000  0.619000  0.532104
# 1971              3.200000e-03  0.116000  0.197000  0.388384
# 1972              3.486600e-05  0.227880  0.583400  0.584462
# 1973              3.300000e-03  0.130000  0.079800  0.395885
# 1975              3.433525e-01  0.282000  0.387100  0.569516
# 1976              9.160000e-01  0.109000  0.071000  0.274695
# 1977              3.600000e-07  0.158833  0.263667  0.416181
# 1979              1.550000e-02  0.050600  0.442000  0.434199
# 1980              3.120000e-01  0.163000  0.754000  0.518111
# 1981              9.430000e-01  0.073600  0.244000  0.613689
# 1982              6.010000e-01  0.143000  0.093600  0.446350
# 1983              8.420000e-01  0.186000  0.304000  0.345302
# 1984              9.600000e-01  0.103000  0.601000  0.681101
# 1985              8.940000e-04  0.064100  0.657000  0.632342
# 1986              9.420000e-01  0.107000  0.098800  0.401958
# 1988              1.530000e-06  0.298000  0.624000  0.497729
# 1989              6.504150e-01  0.197200  0.722500  0.663468
# 1990              9.260000e-01  0.098600  0.092200  0.320129
# 1991              4.566183e-01  0.169625  0.426250  0.433830
# 1992              4.610118e-01  0.114000  0.335500  0.400568
# 1995              8.360000e-01  0.046600  0.475000  0.574164
# 1998              9.200000e-01  0.100000  0.037800  0.283765
# 2002              5.773665e-01  0.186900  0.364200  0.542793
# 2003              1.180000e-01  0.337000  0.278000  0.582324
# 2004              4.720000e-05  0.300000  0.818000  0.485390
# 2007              6.852500e-01  0.098650  0.163100  0.492371
# 2009              3.083340e-01  0.222433  0.361800  0.669398
# 2010              9.136667e-01  0.086200  0.124667  0.284128
# 2011              0.000000e+00  0.113000  0.271000  0.593778
# 2012              9.134325e-02  0.224100  0.412430  0.538192
# 2013              9.205433e-04  0.316000  0.496778  0.597431
# 2014              7.472144e-04  0.204856  0.473222  0.590700
# 2015              1.659690e-01  0.268309  0.448364  0.592461
# 2016              1.387235e-01  0.179562  0.395100  0.494912
# 2017              5.967852e-02  0.159815  0.512264  0.549344
# 2018              3.601743e-02  0.195924  0.542055  0.583623
# 2019              3.388898e-02  0.162648  0.547871  0.608093
# 2020              3.967192e-02  0.197083  0.530802  0.601657
# 2021              2.945455e-04  0.187436  0.647545  0.625435

# %%
# Reset the index 
songs_by_year_df.reset_index(inplace = True)
songs_by_year_df

# %%
# Get the descriptive statistics for the songs by year
songs_by_year_df.describe()
# Out:
#        release_year  danceability  popularity     energy  speechiness  \
# count     41.000000     41.000000   41.000000  41.000000    41.000000
# mean    1993.756098      0.482978   68.922678   0.464839     0.072882
# std       18.228797      0.199661    5.878821   0.278104     0.052585
# min     1949.000000      0.128000   61.000000   0.012800     0.030800
# 25%     1980.000000      0.338000   65.000000   0.211878     0.038400
# 50%     1991.000000      0.454000   68.000000   0.504575     0.051400
# 75%     2011.000000      0.594889   71.238095   0.687796     0.072691
# max     2021.000000      0.935000   85.000000   0.932000     0.225000
#
#        acousticness  instrumentalness   liveness    valence      tempo
# count     41.000000         41.000000  41.000000  41.000000  41.000000
# mean       0.430198          0.351424   0.169026   0.395971   0.507599
# std        0.367967          0.378229   0.079961   0.205394   0.115197
# min        0.000056          0.000000   0.046600   0.037800   0.274695
# 25%        0.112000          0.003200   0.107000   0.263667   0.416181
# 50%        0.326000          0.165969   0.162648   0.395100   0.538192
# 75%        0.745809          0.685250   0.204856   0.542055   0.593778
# max        0.995000          0.960000   0.349000   0.818000   0.681101

# %%
# Categorize songs by year based on the bins.
year_bins = [0, 1981, 1991, 2011, 2022]
songs_by_year_df['release_year'].groupby(pd.cut(songs_by_year_df['release_year'], year_bins)).count()
# Out:
# release_year
# (0, 1981]       12
# (1981, 1991]     9
# (1991, 2011]    10
# (2011, 2022]    10
# Name: release_year, dtype: int64

# %%
# Establish the year bins and group names.
year_bins = [0, 1981, 1991,2011, 2022]
group_names = ["<1980", "1981-1990", "1991-2010",  "2011-2021"]

# Categorize songs by year based on the bins.
songs_by_year_df["songs by period"] = pd.cut(songs_by_year_df['release_year'], year_bins, labels=group_names)
songs_by_year_df
# Out:
#     release_year  danceability  popularity    energy  speechiness  \
# 0           1949      0.469000   71.000000  0.012800     0.119000
# 1           1967      0.396000   72.000000  0.473000     0.034500
# 2           1970      0.564000   79.000000  0.932000     0.055400
# 3           1971      0.338000   81.000000  0.340000     0.033900
# 4           1972      0.495200   67.400000  0.563400     0.044000
# 5           1973      0.212000   65.000000  0.301000     0.038400
# 6           1975      0.349500   65.500000  0.369000     0.030800
# 7           1976      0.136000   66.000000  0.164000     0.036400
# 8           1977      0.428000   75.000000  0.430333     0.063033
# 9           1979      0.592000   61.000000  0.882000     0.046800
# 10          1980      0.933000   84.000000  0.528000     0.161000
# 11          1981      0.454000   66.000000  0.013900     0.051400
# 12          1982      0.233000   61.000000  0.025200     0.034600
# 13          1983      0.275000   70.000000  0.157000     0.063600
# 14          1984      0.358000   62.000000  0.167000     0.035400
# 15          1985      0.667000   65.000000  0.655000     0.036700
# 16          1986      0.128000   63.000000  0.132000     0.035300
# 17          1988      0.935000   67.000000  0.805000     0.225000
# 18          1989      0.389000   64.250000  0.504575     0.043050
# 19          1990      0.355000   61.000000  0.016400     0.039600
# 20          1991      0.314250   66.250000  0.503300     0.035075
# 21          1992      0.336500   69.000000  0.418315     0.037400
# 22          1995      0.404000   75.000000  0.720000     0.062300
# 23          1998      0.343000   63.000000  0.034200     0.040600
# 24          2002      0.308300   68.000000  0.267200     0.050467
# 25          2003      0.743000   85.000000  0.446000     0.068300
# 26          2004      0.724000   66.000000  0.891000     0.099500
# 27          2007      0.317750   64.250000  0.211878     0.042200
# 28          2009      0.453000   68.333333  0.565993     0.069000
# 29          2010      0.269333   63.000000  0.059023     0.043367
# 30          2011      0.588000   65.000000  0.694000     0.038700
# 31          2012      0.533100   73.200000  0.729800     0.057870
# 32          2013      0.594889   70.666667  0.849000     0.057389
# 33          2014      0.535444   74.555556  0.788111     0.056578
# 34          2015      0.507182   69.545455  0.688964     0.072691
# 35          2016      0.573231   66.384615  0.574085     0.082631
# 36          2017      0.617909   71.484848  0.687796     0.134818
# 37          2018      0.704059   71.196078  0.649196     0.157133
# 38          2019      0.748218   69.029703  0.603839     0.218555
# 39          2020      0.791952   71.238095  0.567174     0.191779
# 40          2021      0.688273   69.545455  0.637909     0.143945
#
#     acousticness  instrumentalness  liveness   valence     tempo  \
# 0       0.994000      9.370000e-01  0.094100  0.354000  0.342833
# 1       0.326000      1.240000e-04  0.109000  0.385000  0.628747
# 2       0.013000      1.690000e-01  0.349000  0.619000  0.532104
# 3       0.580000      3.200000e-03  0.116000  0.197000  0.388384
# 4       0.152920      3.486600e-05  0.227880  0.583400  0.584462
# 5       0.963000      3.300000e-03  0.130000  0.079800  0.395885
# 6       0.465500      3.433525e-01  0.282000  0.387100  0.569516
# 7       0.911000      9.160000e-01  0.109000  0.071000  0.274695
# 8       0.384333      3.600000e-07  0.158833  0.263667  0.416181
# 9       0.008840      1.550000e-02  0.050600  0.442000  0.434199
# 10      0.112000      3.120000e-01  0.163000  0.754000  0.518111
# 11      0.995000      9.430000e-01  0.073600  0.244000  0.613689
# 12      0.975000      6.010000e-01  0.143000  0.093600  0.446350
# 13      0.890000      8.420000e-01  0.186000  0.304000  0.345302
# 14      0.899000      9.600000e-01  0.103000  0.601000  0.681101
# 15      0.049100      8.940000e-04  0.064100  0.657000  0.632342
# 16      0.744000      9.420000e-01  0.107000  0.098800  0.401958
# 17      0.014300      1.530000e-06  0.298000  0.624000  0.497729
# 18      0.674500      6.504150e-01  0.197200  0.722500  0.663468
# 19      0.995000      9.260000e-01  0.098600  0.092200  0.320129
# 20      0.445081      4.566183e-01  0.169625  0.426250  0.433830
# 21      0.496663      4.610118e-01  0.114000  0.335500  0.400568
# 22      0.000056      8.360000e-01  0.046600  0.475000  0.574164
# 23      0.991000      9.200000e-01  0.100000  0.037800  0.283765
# 24      0.649267      5.773665e-01  0.186900  0.364200  0.542793
# 25      0.003900      1.180000e-01  0.337000  0.278000  0.582324
# 26      0.003440      4.720000e-05  0.300000  0.818000  0.485390
# 27      0.745809      6.852500e-01  0.098650  0.163100  0.492371
# 28      0.356737      3.083340e-01  0.222433  0.361800  0.669398
# 29      0.975333      9.136667e-01  0.086200  0.124667  0.284128
# 30      0.009480      0.000000e+00  0.113000  0.271000  0.593778
# 31      0.143941      9.134325e-02  0.224100  0.412430  0.538192
# 32      0.040810      9.205433e-04  0.316000  0.496778  0.597431
# 33      0.081487      7.472144e-04  0.204856  0.473222  0.590700
# 34      0.308666      1.659690e-01  0.268309  0.448364  0.592461
# 35      0.274098      1.387235e-01  0.179562  0.395100  0.494912
# 36      0.177947      5.967852e-02  0.159815  0.512264  0.549344
# 37      0.199342      3.601743e-02  0.195924  0.542055  0.583623
# 38      0.182461      3.388898e-02  0.162648  0.547871  0.608093
# 39      0.162108      3.967192e-02  0.197083  0.530802  0.601657
# 40      0.243983      2.945455e-04  0.187436  0.647545  0.625435
#
#    songs by period
# 0            <1980
# 1            <1980
# 2            <1980
# 3            <1980
# 4            <1980
# 5            <1980
# 6            <1980
# 7            <1980
# 8            <1980
# 9            <1980
# 10           <1980
# 11           <1980
# 12       1981-1990
# 13       1981-1990
# 14       1981-1990
# 15       1981-1990
# 16       1981-1990
# 17       1981-1990
# 18       1981-1990
# 19       1981-1990
# 20       1981-1990
# 21       1991-2010
# 22       1991-2010
# 23       1991-2010
# 24       1991-2010
# 25       1991-2010
# 26       1991-2010
# 27       1991-2010
# 28       1991-2010
# 29       1991-2010
# 30       1991-2010
# 31       2011-2021
# 32       2011-2021
# 33       2011-2021
# 34       2011-2021
# 35       2011-2021
# 36       2011-2021
# 37       2011-2021
# 38       2011-2021
# 39       2011-2021
# 40       2011-2021

# %%
# Creating group of audio features by period
popularity_by_period_df = songs_by_year_df.groupby("songs by period").mean()['popularity']
danceability_by_period_df = songs_by_year_df.groupby("songs by period").mean()['danceability']
energy_by_period_df = songs_by_year_df.groupby("songs by period").mean()['energy']
speechiness_by_period_df = songs_by_year_df.groupby("songs by period").mean()['speechiness']
acousticness_by_period_df = songs_by_year_df.groupby("songs by period").mean()['acousticness']
instrumentalness_by_period_df = songs_by_year_df.groupby("songs by period").mean()['instrumentalness']
liveness_by_period_df = songs_by_year_df.groupby("songs by period").mean()['liveness']
valence_by_period_df = songs_by_year_df.groupby("songs by period").mean()['valence']
tempo_by_period_df = songs_by_year_df.groupby("songs by period").mean()['tempo']

# # Prints to check data integrity
# print(len(danceability_by_period_df))
# print(len(popularity_by_period_df))
# print(len(speechiness_by_period_df))
# print(len(acousticness_by_period_df))
# print(len(instrumentalness_by_period_df))
# print(len(liveness_by_period_df))
# print(len(valence_by_period_df))
# print(len(tempo_by_period_df))


# Merging into a Dataframe with audio features by popularity
songs_by_period_df = pd.concat([popularity_by_period_df, danceability_by_period_df,energy_by_period_df, speechiness_by_period_df, acousticness_by_period_df, instrumentalness_by_period_df, liveness_by_period_df, valence_by_period_df, tempo_by_period_df], axis =1)
print(len(songs_by_period_df))
songs_by_period_df

# Reset index
songs_by_period_df = songs_by_period_df.reset_index()
songs_by_period_df
# Out:
# 4
#   songs by period  popularity  danceability    energy  speechiness  \
# 0           <1980   71.075000      0.447225  0.417453     0.059553
# 1       1981-1990   64.388889      0.406028  0.329497     0.060925
# 2       1991-2010   68.658333      0.448688  0.430761     0.055183
# 3       2011-2021   70.684647      0.629426  0.677587     0.117339
#
#    acousticness  instrumentalness  liveness   valence     tempo
# 0      0.492133          0.303543  0.155251  0.364997  0.474901
# 1      0.631776          0.597659  0.151836  0.402150  0.491357
# 2      0.423168          0.481968  0.160478  0.322907  0.490868
# 3      0.181484          0.056725  0.209573  0.500643  0.578185

# %%
plt.figure(figsize=(15,10))
plt.matshow(songs_by_period_df.corr(),fignum=1 )

# %%
# Create graph
fig, ax = plt.subplots(3,3,figsize=(15,20))
x_axis = np.arange(len(songs_by_period_df))
tick_locations = [value for value in x_axis]

# Graph the plots
ax[0,0].plot(x_axis, songs_by_period_df['popularity'], color = 'r', linewidth=5, marker = 'o', markersize = 12)
ax[0,1].plot(x_axis, songs_by_period_df['danceability'], color = 'g', linewidth=5, marker = 'o', markersize= 12 )
ax[0,2].plot(x_axis, songs_by_period_df['energy'], color = 'b', linewidth=5, marker = 'o', markersize= 12 )
ax[1,0].plot(x_axis, songs_by_period_df['speechiness'], color = 'c', linewidth=5, marker = 'o', markersize= 12 )
ax[1,1].plot(x_axis, songs_by_period_df['acousticness'], color = 'm', linewidth=5, marker = 'o', markersize= 12 )
ax[1,2].plot(x_axis, songs_by_period_df['instrumentalness'] , color = 'y', linewidth=5, marker = 'o', markersize= 12 )
ax[2,0].plot(x_axis, songs_by_period_df['liveness'], color = 'orange', linewidth=5, marker = 'o', markersize= 12  )
ax[2,1].plot(x_axis, songs_by_period_df['valence'], color = 'olive', linewidth=5, marker = 'o', markersize= 12 )
ax[2,2].plot(x_axis, songs_by_period_df['tempo'], color = 'darkviolet', linewidth=5, marker = 'o',markersize= 12)

# Set the xticks
ax[0,0].set_xticks(tick_locations)
ax[0,1].set_xticks(tick_locations)
ax[0,2].set_xticks(tick_locations)
ax[1,0].set_xticks(tick_locations)
ax[1,1].set_xticks(tick_locations)
ax[1,2].set_xticks(tick_locations)
ax[2,0].set_xticks(tick_locations)
ax[2,1].set_xticks(tick_locations)
ax[2,2].set_xticks(tick_locations)

# Set the xticks labels
ax[0,0].set_xticklabels(songs_by_period_df['songs by period'], rotation='45')
ax[0,1].set_xticklabels(songs_by_period_df['songs by period'], rotation='45')
ax[0,2].set_xticklabels(songs_by_period_df['songs by period'], rotation='45')
ax[1,0].set_xticklabels(songs_by_period_df['songs by period'], rotation='45')
ax[1,1].set_xticklabels(songs_by_period_df['songs by period'], rotation='45')
ax[1,2].set_xticklabels(songs_by_period_df['songs by period'], rotation='45')
ax[2,0].set_xticklabels(songs_by_period_df['songs by period'], rotation='45')
ax[2,1].set_xticklabels(songs_by_period_df['songs by period'], rotation='45')
ax[2,2].set_xticklabels(songs_by_period_df['songs by period'], rotation='45')

# Set the xlabel
ax[0,0].set_xlabel('period', fontsize=20)
ax[0,1].set_xlabel('period', fontsize=20)
ax[0,2].set_xlabel('period', fontsize=20)
ax[1,0].set_xlabel('period', fontsize=20)
ax[1,1].set_xlabel('period', fontsize=20)
ax[1,2].set_xlabel('period', fontsize=20)
ax[2,0].set_xlabel('period', fontsize=20)
ax[2,1].set_xlabel('period', fontsize=20)
ax[2,2].set_xlabel('period', fontsize=20)

# Set the ylabel
ax[0,0].set_ylabel('popularity', fontsize=20)
ax[0,1].set_ylabel('danceability', fontsize=20)
ax[0,2].set_ylabel('energy', fontsize=20)
ax[1,0].set_ylabel('speechiness', fontsize=20)
ax[1,1].set_ylabel('acousticness', fontsize=20)
ax[1,2].set_ylabel('instrumentalness', fontsize=20)
ax[2,0].set_ylabel('liveness', fontsize=20)
ax[2,1].set_ylabel('valence', fontsize=20)
ax[2,2].set_ylabel('tempo', fontsize=20)

# Set the title
ax[0,0].set_title('popularity based on period', fontsize=22)
ax[0,1].set_title('danceability based on period', fontsize=22)
ax[0,2].set_title('energy based on period', fontsize=22)
ax[1,0].set_title('speechiness based on period', fontsize=22)
ax[1,1].set_title('acousticness based on period', fontsize=22)
ax[1,2].set_title('instrumentalness based on period', fontsize=22)
ax[2,0].set_title('liveness based on period', fontsize=22)
ax[2,1].set_title('valence  based on period', fontsize=22)
ax[2,2].set_title('tempo  based on period', fontsize=22)

plt.tight_layout(pad=0.6, w_pad=1.0, h_pad=1.5)

# %%
# Creating group of audio features by artist
popularity_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['popularity']
danceability_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['danceability']
energy_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['energy']
speechiness_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['speechiness']
acousticness_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['acousticness']
instrumentalness_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['instrumentalness']
liveness_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['liveness']
valence_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['valence']
tempo_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['tempo']

# # Prints to check data integrity
# print(len(danceability_by_artist_df))
# print(len(popularity_by_artist_df))
# print(len(speechiness_by_artist_df))
# print(len(acousticness_by_artist_df))
# print(len(instrumentalness_by_artist_df))
# print(len(liveness_by_artist_df))
# print(len(valence_by_artist_df))
# print(len(tempo_by_artist_df))

# Merging into a Dataframe with audio features by artist
songs_by_artist_df = pd.concat([danceability_by_artist_df,popularity_by_artist_df,energy_by_artist_df, speechiness_by_artist_df, acousticness_by_artist_df, instrumentalness_by_artist_df, liveness_by_artist_df, valence_by_artist_df, tempo_by_artist_df], axis =1)
print(len(songs_by_artist_df))
songs_by_artist_df
# Out:
# 209
#                                       danceability  popularity   energy  \
# artist_names  artist_ids
# $NOT          5IbEL2xjRtKsunfmsahLuO         0.847        78.0  0.44800
# 24kGoldn      6fWVd57NKTalqvmjRd2t8Z         0.704        76.5  0.64525
# 88GLAM        2I9SLklAOG0vdMiUUMNxRl         0.764        66.0  0.67200
# Adam Jensen   7ymrIsmp4vE7vAtcS12J4D         0.716        61.0  0.73800
# Afrojack      4D75GcNG95ebPtNvoNVXhz         0.523        66.0  0.86100
# ...                                            ...         ...      ...
# iann dior     6ASri4ePR7RlsvIQgWPJpS         0.695        67.0  0.56600
# ilyTOMMY      4XWaILHqySwH1y6LhlYcsb         0.683        65.0  0.63600
# lil ricefield 2lNuUKrRrHRQ6cYVmrAazL         0.834        61.0  0.75800
# pewdiepie     1JOdUvDAzNy3L37rZ4Nigr         0.795        64.0  0.78900
# tobi lou      4T8NIfZmVY6TJFqVzN6X49         0.734        66.0  0.76500
#
#                                       speechiness  acousticness  \
# artist_names  artist_ids
# $NOT          5IbEL2xjRtKsunfmsahLuO     0.416000       0.81000
# 24kGoldn      6fWVd57NKTalqvmjRd2t8Z     0.081125       0.14125
# 88GLAM        2I9SLklAOG0vdMiUUMNxRl     0.065500       0.01660
# Adam Jensen   7ymrIsmp4vE7vAtcS12J4D     0.040600       0.00180
# Afrojack      4D75GcNG95ebPtNvoNVXhz     0.064400       0.03360
# ...                                           ...           ...
# iann dior     6ASri4ePR7RlsvIQgWPJpS     0.124000       0.00202
# ilyTOMMY      4XWaILHqySwH1y6LhlYcsb     0.097800       0.30200
# lil ricefield 2lNuUKrRrHRQ6cYVmrAazL     0.158000       0.02780
# pewdiepie     1JOdUvDAzNy3L37rZ4Nigr     0.259000       0.01380
# tobi lou      4T8NIfZmVY6TJFqVzN6X49     0.057100       0.24300
#
#                                       instrumentalness  liveness  valence  \
# artist_names  artist_ids
# $NOT          5IbEL2xjRtKsunfmsahLuO          0.000013  0.325000  0.48800
# 24kGoldn      6fWVd57NKTalqvmjRd2t8Z          0.000000  0.167625  0.61875
# 88GLAM        2I9SLklAOG0vdMiUUMNxRl          0.000001  0.103000  0.59400
# Adam Jensen   7ymrIsmp4vE7vAtcS12J4D          0.006960  0.113000  0.34900
# Afrojack      4D75GcNG95ebPtNvoNVXhz          0.000000  0.144000  0.34600
# ...                                                ...       ...      ...
# iann dior     6ASri4ePR7RlsvIQgWPJpS          0.000000  0.167000  0.38800
# ilyTOMMY      4XWaILHqySwH1y6LhlYcsb          0.498000  0.097200  0.61500
# lil ricefield 2lNuUKrRrHRQ6cYVmrAazL          0.000000  0.167000  0.46500
# pewdiepie     1JOdUvDAzNy3L37rZ4Nigr          0.000000  0.113000  0.53800
# tobi lou      4T8NIfZmVY6TJFqVzN6X49          0.000000  0.101000  0.51200
#
#                                          tempo
# artist_names  artist_ids
# $NOT          5IbEL2xjRtKsunfmsahLuO  0.376803
# 24kGoldn      6fWVd57NKTalqvmjRd2t8Z  0.606605
# 88GLAM        2I9SLklAOG0vdMiUUMNxRl  0.706826
# Adam Jensen   7ymrIsmp4vE7vAtcS12J4D  0.607974
# Afrojack      4D75GcNG95ebPtNvoNVXhz  0.598593
# ...                                        ...
# iann dior     6ASri4ePR7RlsvIQgWPJpS  0.377058
# ilyTOMMY      4XWaILHqySwH1y6LhlYcsb  0.753899
# lil ricefield 2lNuUKrRrHRQ6cYVmrAazL  0.518446
# pewdiepie     1JOdUvDAzNy3L37rZ4Nigr  0.706543
# tobi lou      4T8NIfZmVY6TJFqVzN6X49  0.735185
#
# [209 rows x 9 columns]

# %%
# Reset the index
songs_by_artist_df = songs_by_artist_df.reset_index()
songs_by_artist_df

# %%
# Get the statistics for songs by artist
songs_by_artist_df.describe()
# Out:
#        danceability  popularity      energy  speechiness  acousticness  \
# count    209.000000  209.000000  209.000000   209.000000    209.000000
# mean       0.645987   68.476027    0.584450     0.144278      0.242151
# std        0.202376    6.406987    0.236718     0.136906      0.311667
# min        0.000000   61.000000    0.005730     0.000000      0.000025
# 25%        0.510000   63.000000    0.477750     0.045300      0.031099
# 50%        0.683000   66.000000    0.625000     0.080500      0.107000
# 75%        0.803000   73.000000    0.753000     0.225663      0.277000
# max        0.957000   87.000000    0.942000     0.902000      0.995000
#
#        instrumentalness    liveness     valence       tempo
# count        209.000000  209.000000  209.000000  209.000000
# mean           0.120762    0.181705    0.482085    0.564486
# std            0.296102    0.141745    0.211982    0.138780
# min            0.000000    0.033800    0.000000    0.000000
# 25%            0.000000    0.097200    0.343420    0.471048
# 50%            0.000003    0.122667    0.504000    0.580528
# 75%            0.000749    0.227880    0.629000    0.659829
# max            0.954000    0.905000    0.915500    0.923070

# %%
# Establish the popularity bins and group names.
popularity_bins = [0, 63, 66,73, 88]
group_names = ["<62", "63-65", "66-72",  "73-88"]

# Categorize songs by year based on the bins.
songs_by_artist_df["songs by popularity"] = pd.cut(songs_by_artist_df['popularity'], popularity_bins, labels=group_names)
danceability_by_popularity_df = songs_by_artist_df.groupby("songs by popularity").mean()['danceability']
energy_by_popularity_df = songs_by_artist_df.groupby("songs by popularity").mean()['energy']
speechiness_by_popularity_df = songs_by_artist_df.groupby("songs by popularity").mean()['speechiness']
acousticness_by_popularity_df = songs_by_artist_df.groupby("songs by popularity").mean()['acousticness']
instrumentalness_by_popularity_df = songs_by_artist_df.groupby("songs by popularity").mean()['instrumentalness']
liveness_by_popularity_df = songs_by_artist_df.groupby("songs by popularity").mean()['liveness']
valence_by_popularity_df = songs_by_artist_df.groupby("songs by popularity").mean()['valence']
tempo_by_popularity_df = songs_by_artist_df.groupby("songs by popularity").mean()['tempo']
# Out:
#       artist_names              artist_ids  danceability  popularity   energy  \
# 0             $NOT  5IbEL2xjRtKsunfmsahLuO         0.847        78.0  0.44800
# 1         24kGoldn  6fWVd57NKTalqvmjRd2t8Z         0.704        76.5  0.64525
# 2           88GLAM  2I9SLklAOG0vdMiUUMNxRl         0.764        66.0  0.67200
# 3      Adam Jensen  7ymrIsmp4vE7vAtcS12J4D         0.716        61.0  0.73800
# 4         Afrojack  4D75GcNG95ebPtNvoNVXhz         0.523        66.0  0.86100
# ..             ...                     ...           ...         ...      ...
# 204      iann dior  6ASri4ePR7RlsvIQgWPJpS         0.695        67.0  0.56600
# 205       ilyTOMMY  4XWaILHqySwH1y6LhlYcsb         0.683        65.0  0.63600
# 206  lil ricefield  2lNuUKrRrHRQ6cYVmrAazL         0.834        61.0  0.75800
# 207      pewdiepie  1JOdUvDAzNy3L37rZ4Nigr         0.795        64.0  0.78900
# 208       tobi lou  4T8NIfZmVY6TJFqVzN6X49         0.734        66.0  0.76500
#
#      speechiness  acousticness  instrumentalness  liveness  valence     tempo  \
# 0       0.416000       0.81000          0.000013  0.325000  0.48800  0.376803
# 1       0.081125       0.14125          0.000000  0.167625  0.61875  0.606605
# 2       0.065500       0.01660          0.000001  0.103000  0.59400  0.706826
# 3       0.040600       0.00180          0.006960  0.113000  0.34900  0.607974
# 4       0.064400       0.03360          0.000000  0.144000  0.34600  0.598593
# ..           ...           ...               ...       ...      ...       ...
# 204     0.124000       0.00202          0.000000  0.167000  0.38800  0.377058
# 205     0.097800       0.30200          0.498000  0.097200  0.61500  0.753899
# 206     0.158000       0.02780          0.000000  0.167000  0.46500  0.518446
# 207     0.259000       0.01380          0.000000  0.113000  0.53800  0.706543
# 208     0.057100       0.24300          0.000000  0.101000  0.51200  0.735185
#
#     songs by popularity
# 0                 73-88
# 1                 73-88
# 2                 63-65
# 3                   <62
# 4                 63-65
# ..                  ...
# 204               66-72
# 205               63-65
# 206                 <62
# 207               63-65
# 208               63-65
#
# [209 rows x 12 columns]

# %%
# Most popular artists
songs_by_top_9_artist_df = songs_by_artist_df.loc[songs_by_artist_df['popularity'] > 80]
songs_by_top_9_artist_df
# Out:
#             artist_names              artist_ids  danceability  popularity  \
# 16                Avicii  1vCWHaC5f2uS3yhpwWbIA6         0.532        87.0
# 48           Don Toliver  4Gso3d4CscCijv0lmajZWs         0.629        82.0
# 108         Metro Boomin  0iEtIxbK0KxaSlF7G42ZOp         0.901        83.0
# 114  Of Monsters and Men  4dwdTW1Lfiq0cM8nBAqIIz         0.457        82.0
# 132          Roddy Ricch  757aE44tKEUQEqRuT6GnEB         0.896        85.0
# 164    The White Stripes  4F84IBURUo98rz4r61KF70         0.743        85.0
# 173    Twenty One Pilots  3YQKmKGau1PzlVlkL1iodx         0.732        83.0
# 175   Tyler, The Creator  4V8LLVI7PbaPR0K2TGSxFF         0.554        83.0
# 184         XXXTENTACION  15UsOTVnJzReFVN1VCnxy4         0.787        81.8
#
#      energy  speechiness  acousticness  instrumentalness  liveness  valence  \
# 16   0.7830       0.0523       0.00380          0.001200    0.1610   0.6430
# 48   0.6920       0.0376       0.00981          0.331000    0.6030   0.4530
# 108  0.4640       0.0645       0.36800          0.000017    0.2380   0.6380
# 114  0.7570       0.0320       0.02060          0.000000    0.1460   0.4170
# 132  0.5860       0.0559       0.10400          0.000000    0.7900   0.6420
# 164  0.4460       0.0683       0.00390          0.118000    0.3370   0.2780
# 173  0.3960       0.0286       0.08410          0.000036    0.1050   0.5480
# 175  0.4980       0.0685       0.23000          0.000006    0.7950   0.4130
# 184  0.5286       0.2226       0.34298          0.000749    0.1546   0.5274
#
#         tempo songs by popularity
# 16   0.584605               73-88
# 48   0.767732               73-88
# 108  0.513574               73-88
# 114  0.485102               73-88
# 132  0.551111               73-88
# 164  0.582324               73-88
# 173  0.424149               73-88
# 175  0.375201               73-88
# 184  0.572035               73-88

# %%
plt.figure(figsize=(15,10))
plt.matshow(songs_by_top_9_artist_df.corr(), fignum =1)

# %%
# Create graph
fig, ax = plt.subplots(4,2,figsize=(15,20))
x_axis = np.arange(len(songs_by_top_9_artist_df))
tick_locations = [value for value in x_axis]

# Graph the plots
ax[0,0].bar(x_axis, songs_by_top_9_artist_df['danceability'] )
ax[0,1].bar(x_axis, songs_by_top_9_artist_df['energy'] )
ax[1,0].bar(x_axis, songs_by_top_9_artist_df['speechiness'] )
ax[1,1].bar(x_axis, songs_by_top_9_artist_df['acousticness'] )
ax[2,0].bar(x_axis, songs_by_top_9_artist_df['instrumentalness'] )
ax[2,1].bar(x_axis, songs_by_top_9_artist_df['liveness'] )
ax[3,0].bar(x_axis, songs_by_top_9_artist_df['valence'] )
ax[3,1].bar(x_axis, songs_by_top_9_artist_df['tempo'] )

# Set the xticks
ax[0,0].set_xticks(tick_locations)
ax[0,1].set_xticks(tick_locations)
ax[1,0].set_xticks(tick_locations)
ax[1,1].set_xticks(tick_locations)
ax[2,0].set_xticks(tick_locations)
ax[2,1].set_xticks(tick_locations)
ax[3,0].set_xticks(tick_locations)
ax[3,1].set_xticks(tick_locations)

# Set the xticks labels
ax[0,0].set_xticklabels(songs_by_top_9_artist_df['artist_names'], rotation='45')
ax[0,1].set_xticklabels(songs_by_top_9_artist_df['artist_names'], rotation='45')
ax[1,0].set_xticklabels(songs_by_top_9_artist_df['artist_names'], rotation='45')
ax[1,1].set_xticklabels(songs_by_top_9_artist_df['artist_names'], rotation='45')
ax[2,0].set_xticklabels(songs_by_top_9_artist_df['artist_names'], rotation='45')
ax[2,1].set_xticklabels(songs_by_top_9_artist_df['artist_names'], rotation='45')
ax[3,0].set_xticklabels(songs_by_top_9_artist_df['artist_names'], rotation='45')
ax[3,1].set_xticklabels(songs_by_top_9_artist_df['artist_names'], rotation='45')

# Set the xlabel
ax[0,0].set_xlabel('artists', fontsize=20)
ax[0,1].set_xlabel('artists', fontsize=20)
ax[1,0].set_xlabel('artists', fontsize=20)
ax[1,1].set_xlabel('artists', fontsize=20)
ax[2,0].set_xlabel('artists', fontsize=20)
ax[2,1].set_xlabel('artists', fontsize=20)
ax[3,0].set_xlabel('artists', fontsize=20)
ax[3,1].set_xlabel('artists', fontsize=20)

# Set the ylabel
ax[0,0].set_ylabel('danceability', fontsize=20)
ax[0,1].set_ylabel('energy', fontsize=20)
ax[1,0].set_ylabel('speechiness', fontsize=20)
ax[1,1].set_ylabel('acousticness', fontsize=20)
ax[2,0].set_ylabel('instrumentalness', fontsize=20)
ax[2,1].set_ylabel('liveness', fontsize=20)
ax[3,0].set_ylabel('valence', fontsize=20)
ax[3,1].set_ylabel('tempo', fontsize=20)

# Set the title
ax[0,0].set_title('danceability based on artists', fontsize=22)
ax[0,1].set_title('energy based on artists', fontsize=22)
ax[1,0].set_title('speechiness based on artists', fontsize=22)
ax[1,1].set_title('acousticness based on artists', fontsize=22)
ax[2,0].set_title('instrumentalness based on artists', fontsize=22)
ax[2,1].set_title('liveness based on artists', fontsize=22)
ax[3,0].set_title('valence  based on artists', fontsize=22)
ax[3,1].set_title('tempo  based on artists', fontsize=22)

plt.tight_layout(pad=0.6, w_pad=1.0, h_pad=1.5)

# %%
# plot bars in stack manner
# Graph the plots
plt.figure(figsize=(15,8))
x = songs_by_top_9_artist_df['artist_names']
y1 = songs_by_top_9_artist_df['danceability']
y2 = songs_by_top_9_artist_df['energy']
y3 = songs_by_top_9_artist_df['speechiness']
y4 = songs_by_top_9_artist_df['acousticness']
y5 = songs_by_top_9_artist_df['instrumentalness']
y6 = songs_by_top_9_artist_df['liveness']
y7 = songs_by_top_9_artist_df['valence']
y8 = songs_by_top_9_artist_df['tempo']

p1 = plt.bar(x,y1,color = 'r'  )
p2 = plt.bar(x, y2, bottom = y1, color = 'b' )
p3 = plt.bar(x, y3, bottom = y1+y2, color = 'y' )
p4 = plt.bar(x, y4,bottom = y1+y2+y3,  color = 'g' )
p5 = plt.bar(x, y5,bottom = y1+y2+y3+y4,  color = 'orange' )
p6 = plt.bar(x, y6,bottom = y1+y2+y3+y4+y5,  color = 'm' )
p7 = plt.bar(x, y7,bottom = y1+y2+y3+y4+y5+y6,  color = 'c' )
p8 = plt.bar(x, y8,bottom = y1+y2+y3+y4+y5+y6+y7,  color = 'k' )

plt.title('Audio_features for top 9 artists', fontsize = 22)
plt.legend((p1[0], p2[0], p3[0], p4[0],p5[0], p6[0],p7[0], p8[0]), ('danceability', 'energy', 'speechiness', 'acousticness','instrumentalness','liveness','valence', 'tempo' ), bbox_to_anchor = (1.05, 0.6))

# %%
# Creating group of audio features by popularity
#popularity_by_artist_df = popular_songs_data_df.groupby(['artist_names', 'artist_ids']).mean()['popularity']
danceability_by_popularity_df = songs_by_artist_df.groupby("songs by popularity").mean()['danceability']
energy_by_popularity_df = songs_by_artist_df.groupby("songs by popularity").mean()['energy']
speechiness_by_popularity_df = songs_by_artist_df.groupby("songs by popularity").mean()['speechiness']
acousticness_by_popularity_df = songs_by_artist_df.groupby("songs by popularity").mean()['acousticness']
instrumentalness_by_popularity_df = songs_by_artist_df.groupby("songs by popularity").mean()['instrumentalness']
liveness_by_popularity_df = songs_by_artist_df.groupby("songs by popularity").mean()['liveness']
valence_by_popularity_df = songs_by_artist_df.groupby("songs by popularity").mean()['valence']
tempo_by_popularity_df = songs_by_artist_df.groupby("songs by popularity").mean()['tempo']

# # Prints to check data integrity
# print(len(danceability_by_popularity_df))
# print(len(popularity_by_popularity_df))
# print(len(speechiness_by_popularity_df))
# print(len(acousticness_by_popularity_df))
# print(len(instrumentalness_by_popularity_df))
# print(len(liveness_by_popularity_df))
# print(len(valence_by_popularity_df))
# print(len(tempo_by_popularity_df))


# Merging into a Dataframe with audio features by popularity
songs_by_popularity_df = pd.concat([danceability_by_popularity_df,energy_by_popularity_df, speechiness_by_popularity_df, acousticness_by_popularity_df, instrumentalness_by_popularity_df, liveness_by_popularity_df, valence_by_popularity_df, tempo_by_popularity_df], axis =1)
print(len(songs_by_popularity_df))

# # Reset index
songs_by_popularity_df = songs_by_popularity_df.reset_index()
songs_by_popularity_df
# Out:
# 4
#   songs by popularity  danceability    energy  speechiness  acousticness  \
# 0                 <62      0.627818  0.476446     0.158308      0.356747
# 1               63-65      0.644747  0.640412     0.137883      0.214777
# 2               66-72      0.637324  0.609117     0.132138      0.213405
# 3               73-88      0.675655  0.619814     0.147921      0.175251
#
#    instrumentalness  liveness   valence     tempo
# 0          0.269085  0.146370  0.408293  0.536337
# 1          0.101194  0.193158  0.505548  0.572231
# 2          0.072207  0.163514  0.500646  0.571585
# 3          0.029880  0.226906  0.519278  0.579859

# %%
plt.figure(figsize=(15,10))
plt.matshow(songs_by_popularity_df.corr(), fignum = 1)

# %%
# Create graph
fig, ax = plt.subplots(4,2,figsize=(15,20))
x_axis = np.arange(len(songs_by_popularity_df))
tick_locations = [value for value in x_axis]

# Graph the plots
ax[0,0].plot(x_axis, songs_by_popularity_df['danceability'], color = 'r' , linewidth=5, marker = 'o', markersize = 12)
ax[0,1].plot(x_axis, songs_by_popularity_df['energy'], color = 'b', linewidth=5, marker = 'o', markersize = 12 )
ax[1,0].plot(x_axis, songs_by_popularity_df['speechiness'], color = 'c', linewidth=5, marker = 'o', markersize = 12)
ax[1,1].plot(x_axis, songs_by_popularity_df['acousticness'], color = 'm', linewidth=5, marker = 'o', markersize = 12)
ax[2,0].plot(x_axis, songs_by_popularity_df['instrumentalness'] , color = 'y', linewidth=5, marker = 'o', markersize = 12)
ax[2,1].plot(x_axis, songs_by_popularity_df['liveness'], color = 'orange', linewidth=5, marker = 'o', markersize = 12 )
ax[3,0].plot(x_axis, songs_by_popularity_df['valence'], color = 'g' , linewidth=5, marker = 'o', markersize = 12)
ax[3,1].plot(x_axis, songs_by_popularity_df['tempo'], color = 'darkviolet', linewidth=5, marker = 'o', markersize = 12 )


# Set the xticks
ax[0,0].set_xticks(tick_locations)
ax[0,1].set_xticks(tick_locations)
ax[1,0].set_xticks(tick_locations)
ax[1,1].set_xticks(tick_locations)
ax[2,0].set_xticks(tick_locations)
ax[2,1].set_xticks(tick_locations)
ax[3,0].set_xticks(tick_locations)
ax[3,1].set_xticks(tick_locations)

# Set the xticks labels
ax[0,0].set_xticklabels(songs_by_popularity_df['songs by popularity'], rotation='45')
ax[0,1].set_xticklabels(songs_by_popularity_df['songs by popularity'], rotation='45')
ax[1,0].set_xticklabels(songs_by_popularity_df['songs by popularity'], rotation='45')
ax[1,1].set_xticklabels(songs_by_popularity_df['songs by popularity'], rotation='45')
ax[2,0].set_xticklabels(songs_by_popularity_df['songs by popularity'], rotation='45')
ax[2,1].set_xticklabels(songs_by_popularity_df['songs by popularity'], rotation='45')
ax[3,0].set_xticklabels(songs_by_popularity_df['songs by popularity'], rotation='45')
ax[3,1].set_xticklabels(songs_by_popularity_df['songs by popularity'], rotation='45')

# Set the xlabel
ax[0,0].set_xlabel('popularity', fontsize=20)
ax[0,1].set_xlabel('popularity', fontsize=20)
ax[1,0].set_xlabel('popularity', fontsize=20)
ax[1,1].set_xlabel('popularity', fontsize=20)
ax[2,0].set_xlabel('popularity', fontsize=20)
ax[2,1].set_xlabel('popularity', fontsize=20)
ax[3,0].set_xlabel('popularity', fontsize=20)
ax[3,1].set_xlabel('popularity', fontsize=20)

# Set the ylabel
ax[0,0].set_ylabel('danceability', fontsize=20)
ax[0,1].set_ylabel('energy', fontsize=20)
ax[1,0].set_ylabel('speechiness', fontsize=20)
ax[1,1].set_ylabel('acousticness', fontsize=20)
ax[2,0].set_ylabel('instrumentalness', fontsize=20)
ax[2,1].set_ylabel('liveness', fontsize=20)
ax[3,0].set_ylabel('valence', fontsize=20)
ax[3,1].set_ylabel('tempo', fontsize=20)

# Set the title
ax[0,0].set_title('danceability based on popularity', fontsize=22)
ax[0,1].set_title('energy based on popularity', fontsize=22)
ax[1,0].set_title('speechiness based on popularity', fontsize=22)
ax[1,1].set_title('acousticness based on popularity', fontsize=22)
ax[2,0].set_title('instrumentalness based on popularity', fontsize=22)
ax[2,1].set_title('liveness based on popularity', fontsize=22)
ax[3,0].set_title('valence  based on popularity', fontsize=22)
ax[3,1].set_title('tempo  based on popularity', fontsize=22)

plt.tight_layout(pad=0.6, w_pad=1.0, h_pad=1.5)

# %%
# plot bars in stack manner
# Graph the plots
plt.figure(figsize=(15,8))
x = songs_by_popularity_df['songs by popularity']
y1 = songs_by_popularity_df['danceability']
y2 = songs_by_popularity_df['energy']
y3 = songs_by_popularity_df['speechiness']
y4 = songs_by_popularity_df['acousticness']
y5 = songs_by_popularity_df['instrumentalness']
y6 = songs_by_popularity_df['liveness']
y7 = songs_by_popularity_df['valence']
y8 = songs_by_popularity_df['tempo']

p1 = plt.barh(x,y1,color = 'r'  )
p2 = plt.barh(x, y2, left = y1, color = 'b' )
p3 = plt.barh(x, y3, left = y1+y2, color = 'y' )
p4 = plt.barh(x, y4, left = y1+y2+y3,  color = 'g' )
p5 = plt.barh(x, y5, left = y1+y2+y3+y4,  color = 'orange' )
p6 = plt.barh(x, y6, left = y1+y2+y3+y4+y5,  color = 'm' )
p7 = plt.barh(x, y7, left = y1+y2+y3+y4+y5+y6,  color = 'c' )
p8 = plt.barh(x, y8, left = y1+y2+y3+y4+y5+y6+y7,  color = 'k' )

plt.title('Audio_features by popularity', fontsize = 22)
plt.legend((p1[0], p2[0], p3[0], p4[0],p5[0], p6[0],p7[0], p8[0]), ('danceability', 'energy', 'speechiness', 'acousticness','instrumentalness','liveness','valence', 'tempo' ), bbox_to_anchor = (1.05, 0.6))

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-35d04405709a> in <module>
#       1 plt.matshow(songs_by_popularity_df.corr())
# ----> 2 corr.style.background_gradient(cmap='coolwarm').set_precision(2)
#
# NameError: name 'corr' is not defined

# %%
songs_by_popularity_df
# Out:
#   songs by popularity  danceability    energy  speechiness  acousticness  \
# 0                 <62      0.627818  0.476446     0.158308      0.356747
# 1               63-65      0.644747  0.640412     0.137883      0.214777
# 2               66-72      0.637324  0.609117     0.132138      0.213405
# 3               73-88      0.675655  0.619814     0.147921      0.175251
#
#    instrumentalness  liveness   valence     tempo
# 0          0.269085  0.146370  0.408293  0.536337
# 1          0.101194  0.193158  0.505548  0.572231
# 2          0.072207  0.163514  0.500646  0.571585
# 3          0.029880  0.226906  0.519278  0.579859
